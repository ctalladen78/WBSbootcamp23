# %% [markdown]
# # From SQL to Pandas Challenge 2
#
# First, we'll need to set up the tables again, so we can work with them.

# %%
# import libraries
import pandas as pd

# load data
# This code is made to load our data stored on Google Drive
def gd_path(file_id):
    """Generate a shareable link from Google Drive file id."""
    return f"https://drive.google.com/uc?export=download&id={file_id}"

# Google Drive file ids
files_id = {
    "titleauthor": "1F1JOiYXStWacOBca6coNVfyVtoST7ZgD",
    "titles": "1PLdn50N9GRa53ZbuVWo0l47F_IXdvlEm",
    "stores": "1f-GCgip7O93CpbAkYvOsc21eKnSOSHsQ", 
    "sales": "1fzFc9rwYmVIPaGOFmhLVxCi3kg19vNU2", 
    "roysched": "1zPRZPoFPEMKyrNR5VSENeYFHGCBZmxbs", 
    "publishers": "1s9E8_AVOziTrowb3wyh2jg3PV763VOyq",
    "pub_info": "1OEgogcGKy--EpuVj0kqq7lyBZNGW6YSv", 
    "jobs": "1V1Za8hUdXD-vJOyRdX4aQV5wanIff2eM", 
    "employee": "1h9mUjsVqpP74b1w0x7KOw37n_n9Ulkt5", 
    "discounts": "111dvSxMcCsTgOuV1wDSKFJxO1Xcxd9VS", 
    "authors": "1fEF89Nhe61EebAljKlwFwfEuokK0o6aJ"
}

# Read data from Google Drive
sales = pd.read_csv(gd_path(files_id["sales"]), sep=";")
authors = pd.read_csv(gd_path(files_id["authors"]), sep=";")
publishers = pd.read_csv(gd_path(files_id["publishers"]), sep=";")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   stor_id   21 non-null     int64
#  1   ord_num   21 non-null     object
#  2   ord_date  21 non-null     object
#  3   qty       21 non-null     int64
#  4   payterms  21 non-null     object
#  5   title_id  21 non-null     object
# dtypes: int64(2), object(4)
# memory usage: 1.1+ KB

# %% [markdown]
# ## 1. Select first and last name from authors who have the last name "Ringer"

# %%
authors[authors['au_lname'] == 'Ringer'][['au_lname','au_fname']]
# Out:
#    au_lname au_fname
# 21   Ringer     Anne
# 22   Ringer   Albert

# %% [markdown]
# ### Hint:

# %% [markdown]
# In SQL the syntax is:
#
# ```sql
# SELECT au_fname, au_lname
# FROM authors
# WHERE au_lname="Ringer";
# ```

# %% [markdown]
# ## 2. Select the order number and order date of all sales where *exactly* 20 books where sold.

# %%
sales[sales['qty'] == 20][['ord_num','ord_date']]
# Out:
#     ord_num             ord_date
# 6     P2121  1992-06-15 00:00:00
# 7     P2121  1992-06-15 00:00:00
# 8   N914008  1994-09-14 00:00:00
# 10   P3087a  1993-05-29 00:00:00

# %% [markdown]
# ### Hint:

# %% [markdown]
# In SQL the syntax is:
#
# ```sql
# SELECT ord_num, ord_date, qty
# FROM sales
# WHER'E qty = 20;
# ```

# %% [markdown]
# ## 3. Select first and last name from authors whose last name is "Ringer" and first name is "Anne"

# %%
authors[(authors['au_lname'] == 'Ringer') & (authors['au_fname'] == 'Anne')][['au_lname','au_fname']]
# Out:
#    au_lname au_fname
# 21   Ringer     Anne

# %% [markdown]
# ### Hint:

# %% [markdown]
# In SQL the syntax is:
#
# ```sql
# SELECT au_fname, au_lname
# FROM authors
# WHERE au_fname = "Anne"
# AND au_lname = "Ringer";
# ```

# %% [markdown]
# ### 4. Select the name and city of publishers based in either Germany or France

# %%
publishers[(publishers['country'] == 'Germnay') | (publishers['country'] == 'France')][['pub_name','city']]
# Out:
#              pub_name   city
# 7  Lucerne Publishing  Paris

# %% [markdown]
# ### Hint:

# %% [markdown]
# In SQL the syntax is:
#
# ```sql
# SELECT pub_name, city
# FROM publishers
# WHERE country='Germany'
# OR country='France';
# ```

# %% [markdown]
# ## 5. Select first name, last name and city from authors whose first name is "Dean" and whose city is either "Oakland" or "Berkeley"

# %%
authors[((authors['city'] == 'Oakland') | (authors['city'] == 'Berkeley')) & authors['au_fname'] == 'Dean'][['au_fname','au_lname','city']]
# Out:
# Empty DataFrame
# Columns: [au_fname, au_lname, city]
# Index: []

# %% [markdown]
# ### Hint:

# %% [markdown]
# In SQL the syntax is:
#
# ```sql
# SELECT au_fname,au_lname,city
# FROM authors
# WHERE au_fname ="Dean"
# AND (city ="Oakland" OR city = "Berkeley");
# ```

# %% [markdown]
# ## 6. Select the name, city and country of publishers, not based in the USA

# %%
publishers[publishers['country']!= 'USA'][['pub_name','city','country']]
# Out:
#              pub_name     city  country
# 5               GGG&G  Mnchen  Germany
# 7  Lucerne Publishing    Paris   France

# %% [markdown]
# ### Hint:

# %% [markdown]
# The SQL syntax is:
# ```sql
# SELECT pub_name, city,country
# FROM publishers
# WHERE NOT country="USA";
# ```

# %% [markdown]
# ## 7. Select first name, last name and city from authors whose city is "Oakland" or "Berkeley", and last name is **not** "Straight"

# %%
authors[((authors['city'] == 'Oakland') | (authors['city'] == 'Berkeley')) & authors['au_lname'] != 'Straight'][['au_fname','au_lname','city']]
# Out:
#        au_fname        au_lname            city
# 0       Johnson           White      Menlo Park
# 1      Marjorie           Green         Oakland
# 2        Cheryl          Carson        Berkeley
# 3       Michael         O'Leary        San Jose
# 4          Dean        Straight         Oakland
# 5       Meander           Smith        Lawrence
# 6       Abraham          Bennet        Berkeley
# 7           Ann            Dull       Palo Alto
# 8          Burt      Gringlesby          Covelo
# 9      Charlene        Locksley   San Francisco
# 10  Morningstar          Greene       Nashville
# 11     Reginald  Blotchet-Halls       Corvallis
# 12        Akiko        Yokomoto    Walnut Creek
# 13        Innes    del Castillo       Ann Arbor
# 14       Michel        DeFrance            Gary
# 15         Dirk        Stringer         Oakland
# 16      Stearns      MacFeather         Oakland
# 17        Livia          Karsen         Oakland
# 18       Sylvia        Panteley       Rockville
# 19       Sheryl          Hunter       Palo Alto
# 20      Heather        McBadden       Vacaville
# 21         Anne          Ringer  Salt Lake City
# 22       Albert          Ringer  Salt Lake City

# %% [markdown]
# ### Hint:

# %% [markdown]
# In SQL the syntax is:
# ```sql
# SELECT au_fname, au_lname, city
# FROM authors
# WHERE (city = "Oakland" OR city = "Berkeley")
# AND NOT au_lname = "Straight";
# ```
