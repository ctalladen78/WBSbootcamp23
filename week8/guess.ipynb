# %%
# random guess using manually selected feature

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

housing_maindf = pd.read_csv('~/Documents/datacamp/WBS-School/wbs-housing-iter-0-2/housing-classification-iter-0-2.csv')

housing_df = housing_maindf.copy()

# %%
# housing_df.info()

# %%
X = housing_df.copy()

# %%
# target
y = X.pop("Expensive")

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=31416)

# %%
X_train.columns.values
# Out:
# array(['LotArea', 'LotFrontage', 'TotalBsmtSF', 'BedroomAbvGr',
#        'Fireplaces', 'PoolArea', 'GarageCars', 'WoodDeckSF',
#        'ScreenPorch'], dtype=object)

# %%
# Your task
# Define a rule that determines whether a house is expensive or not.
# Write a function that takes a DataFrame of housing data as an input
# and based on the rule you defined, outputs a list with predictions 
# about whether a house is expensive or not (1 or 0).
# Use Scikit-Learn’s accuracy_score to check how well your rule makes predictions
# on the test set.

# %%
# https://www.oreilly.com/library/view/practical-linear-algebra/9781098120603/ch04.html

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
corr = housing_df.corr()
fig, ax = plt.subplots(figsize=(7,7))
sns.heatmap(corr,annot=True)
# Out:
# <AxesSubplot:>

# %%
# observation:
# TotalBsmtSF -> WoodDeckSF, GarageCars, Fireplaces
[0.23, 0.43, 0.34]
# Out:
# [0.23, 0.43, 0.34]

# %%
# https://numpy.org/doc/stable/reference/random/generated/numpy.random.Generator.choice.html

# %%
from numpy.random import choice
def get_random(a,i,j,k):
    return choice([3,a],p=[i,j,k])

# %%
a = housing_df['TotalBsmtSF']
i = housing_df['WoodDeckSF']
j = housing_df['GarageCars']
k = housing_df['Fireplaces']

housing_df.loc[:,'guess_rate'] = (i*(0.23) + j*(0.43)+ k*(0.34))/3

# %%
housing_df.head(3)
# Out:
#    LotArea  LotFrontage  TotalBsmtSF  BedroomAbvGr  Fireplaces  PoolArea  \
# 0     8450         65.0          856             3           0         0
# 1     9600         80.0         1262             3           1         0
# 2    11250         68.0          920             3           1         0
#
#    GarageCars  WoodDeckSF  ScreenPorch  Expensive  guess_rate
# 0           2           0            0          0    0.286667
# 1           2         298            0          0   23.246667
# 2           2           0            0          0    0.400000

# %%
from sklearn.metrics import accuracy_score

# %%
# should be same nrows
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# before split
print(housing_df['guess_rate'].shape)
print(X.shape)
print(y.shape)

# %%
# prediction = housing_df.predict(X_test) 
# prediction = housing_df.predict([[21,1]])
# y_test = [2]
# score = accuracy_score(y_test,prediction)

# %%
train_accuracy = accuracy_score(y_true = y_train,
                                 y_pred = housing_df['guess_rate'].to_numpy()
                                 )

round(train_accuracy, 2)
